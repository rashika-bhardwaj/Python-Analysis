# %%
import pandas as pd
df=pd.read_csv("cars.csv")
df.head()
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                 NaN  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
# ...

# %%
# Dimension
df.shape
# Out:
# (93, 28)

# %%
# Column Headers
df.columns
# Out:
# Index(['id', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
# Information of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             56 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %%
# Statistical details/ Descriptive Analysis
df.describe()
# Out:
#               id  Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# count  93.000000  93.000000  93.000000  93.000000  93.000000    93.000000
# mean   47.000000  17.125806  19.509677  21.898925  22.365591    29.086022
# std    26.990739   8.746029   9.659430  11.030457   5.619812     5.331726
# min     1.000000   6.700000   7.400000   7.900000  15.000000    20.000000
# 25%    24.000000  10.800000  12.200000  14.700000  18.000000    26.000000
# 50%    47.000000  14.700000  17.700000  19.600000  21.000000    28.000000
# 75%    70.000000  20.300000  23.300000  25.300000  25.000000    31.000000
# max    93.000000  45.400000  61.900000  80.000000  46.000000    50.000000
#
#        EngineSize  Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# count   93.000000   93.000000    93.000000     93.000000           93.000000
# mean     2.667742  143.827957  5280.645161   2332.204301           16.664516
# ...

# %% [markdown]
# EDA (Exploratory Data Analysis)

# %%
# Manufacturer
df['Manufacturer']
# Out:
# 0          Acura
# 1          Acura
# 2           Audi
# 3           Audi
# 4            BMW
#          ...
# 88    Volkswagen
# 89    Volkswagen
# 90    Volkswagen
# 91         Volvo
# 92         Volvo
# Name: Manufacturer, Length: 93, dtype: object

# %%
# Unique Values in column
df['Manufacturer'].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrylser', 'Chrysler', 'Dodge', 'Eagle', 'Ford', 'Geo', 'Honda',
#        'Hyundai', 'Infiniti', 'Lexus', 'Lincoln', 'Mazda',
#        'Mercedes-Benz', 'Mercury', 'Mitsubishi', 'Nissan', 'Oldsmobile',
#        'Plymouth', 'Pontiac', 'Saab', 'Saturn', 'Subaru', 'Suzuki',
#        'Toyota', 'Volkswagen', 'Volvo'], dtype=object)

# %%
# number of unique values
df['Manufacturer'].nunique()
# Out:
# 32

# %%
df['Type'].unique()
# Out:
# array(['Small', 'Midsize', 'Compact', 'Large', 'Sporty', 'Van'],
#       dtype=object)

# %%
# display count of each value value_counts()
df['Type'].value_counts()
# Out:
# Type
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: count, dtype: int64

# %%
df['Manufacturer'].value_counts()
# Out:
# Manufacturer
# Chevrolet        8
# Ford             8
# Dodge            6
# Mazda            5
# Pontiac          5
# Oldsmobile       4
# Hyundai          4
# Buick            4
# Nissan           4
# Toyota           4
# Volkswagen       4
# Subaru           3
# Honda            3
# Geo              2
# Audi             2
# Acura            2
# Volvo            2
# Mitsubishi       2
# Mercedes-Benz    2
# Lexus            2
# Chrysler         2
# Cadillac         2
# Eagle            2
# Lincoln          2
# Mercury          2
# Infiniti         1
# BMW              1
# Chrylser         1
# Plymouth         1
# Saab             1
# Saturn           1
# Suzuki           1
# Name: count, dtype: int64

# %%
df.value_counts('AirBags')
# Out:
# AirBags
# Driver only           42
# Driver & Passenger    14
# Name: count, dtype: int64

# %%
df['Model'].value_counts()
# Out:
# Model
# Integra    1
# Legend     1
# 90         1
# 100        1
# 535i       1
#           ..
# Eurovan    1
# Passat     1
# Corrado    1
# 240        1
# 850        1
# Name: count, Length: 93, dtype: int64

# %%
df['Origin'].value_counts()
# Out:
# Origin
# USA        48
# non-USA    45
# Name: count, dtype: int64

# %%
df['Cylinders'].value_counts()
# Out:
# Cylinders
# 4         49
# 6         31
# 8          7
# 3          3
# 5          2
# rotary     1
# Name: count, dtype: int64

# %%
df['MPG.city']
# Out:
# 0     25
# 1     18
# 2     20
# 3     19
# 4     22
#       ..
# 88    17
# 89    21
# 90    18
# 91    21
# 92    20
# Name: MPG.city, Length: 93, dtype: int64

# %%
df['DriveTrain'].value_counts()
# Out:
# DriveTrain
# Front    67
# Rear     16
# 4WD      10
# Name: count, dtype: int64

# %% [markdown]
# DATA CLEANING

# %% [markdown]
# df.isnull() # Returns a DataFrame of the same shape with True for NaNs <br>
# df.notnull() # Opposite of isnull()<br>
# df.isnull().sum() # Total missing values in each column<br>
#
# dropna(): # Drop rows with any missing values <br>
# df.dropna(axis=1) # Drop columns with any missing values

# %%
# Check for missing Values

# isnull(): it returns True when null value is present
df.isnull()

# count of missing values

df.isnull().sum()
# Out:
# id                     0
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags               37
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %%
# Dropping the rows / columns
# dropna() : drops the rows where null value is present
# df.dropna()

# drop the column dropna(axis=1) , inplace=True makes the changes permanent
# df.dropna(axis=1,inplace=True)

# %%
# Filling the missing values
# fillna(), Fills the records whereever it encounters null value
# df['Rear.seat.room'].mean() # mean value is 27.8
# df['Rear.seat.room']=df['Rear.seat.room'].fillna(27.8)

# %%
# df['Rear.seat.room'].isnull().sum()

# %%
# df['AirBags']=df['AirBags'].fillna('Driver only')

# %%
df['Make'].dtype
# Out:
# dtype('O')

# %%
# Modal Value mode (most frequent)
print(df['AirBags'].mode()[0])
print(df['Manufacturer'].mode()[0])
# Out:
# Driver only
# Chevrolet

# %%
df['Luggage.room'].mean()
# Out:
# np.float64(13.890243902439025)

# %%
# For Replacing missing Values / Treating Missing Values

for i in df.columns: # iterating columns from dataframe
  if df[i].dtype=="O": # detecting the data type, if object then
    m=df[i].mode()[0] # modal value
    df[i]=df[i].fillna(m)
  else:
    me=df[i].mean()
    df[i]=df[i].fillna(me)

# %%
df.isnull().sum()
# Out:
# id                    0
# Manufacturer          0
# Model                 0
# Type                  0
# Min.Price             0
# Price                 0
# Max.Price             0
# MPG.city              0
# MPG.highway           0
# AirBags               0
# DriveTrain            0
# Cylinders             0
# EngineSize            0
# Horsepower            0
# RPM                   0
# Rev.per.mile          0
# Man.trans.avail       0
# Fuel.tank.capacity    0
# Passengers            0
# Length                0
# Wheelbase             0
# Width                 0
# Turn.circle           0
# Rear.seat.room        0
# Luggage.room          0
# Weight                0
# Origin                0
# Make                  0
# dtype: int64

# %% [markdown]
# Seggregate columns based on Datatype

# %%
cat_list=[]
con_list=[]
for i in df.columns:
  if df[i].dtype=="object":
    cat_list.append(i)
  else:
    con_list.append(i)

# %%
print(cat_list)
print(con_list)
# Out:
# ['Manufacturer', 'Model', 'Type', 'AirBags', 'DriveTrain', 'Cylinders', 'Man.trans.avail', 'Origin', 'Make']
# ['id', 'Min.Price', 'Price', 'Max.Price', 'MPG.city', 'MPG.highway', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile', 'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room', 'Weight']

# %%
cat_df=df.select_dtypes(include='object')
cat_df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Type', 'AirBags', 'DriveTrain', 'Cylinders',
#        'Man.trans.avail', 'Origin', 'Make'],
#       dtype='object')

# %%
con_df=df.select_dtypes(exclude='object')
con_df.columns
# Out:
# Index(['id', 'Min.Price', 'Price', 'Max.Price', 'MPG.city', 'MPG.highway',
#        'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile', 'Fuel.tank.capacity',
#        'Passengers', 'Length', 'Wheelbase', 'Width', 'Turn.circle',
#        'Rear.seat.room', 'Luggage.room', 'Weight'],
#       dtype='object')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Continuous Column (histogram) <br>
# plt.hist(column_name)

# %%
plt.figure(figsize=(4,4))
plt.hist(df['Price'],edgecolor='black')
plt.title("Histogram of Price")
plt.xlabel("Price of vehicles")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Categorical Column(Countplot) <br>
# sns.countplot(x='colname', data=df)

# %%
# Categorical
plt.figure(figsize=(4,3))
sns.countplot(x='AirBags',data=df)
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.countplot(x='Type',data=df)
plt.show()

# %% [markdown]
# pie Chart<br>
# plt.pie(df['colname'].value_counts())

# %%
plt.figure(figsize=(5,3))
DTC=df['DriveTrain'].value_counts()
plt.pie(DTC,labels=DTC.index)
plt.show()

# %%
# Display cars where Fuel.tanl.Capacity is greater than 12

# %%
# SubSetting
cars_df=df[df['Fuel.tank.capacity']>=12]
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
cars_df['Type'].value_counts()
# Out:
# Type
# Midsize    22
# Compact    16
# Small      14
# Sporty     12
# Large      11
# Van         9
# Name: count, dtype: int64

# %%
cars_df['EngineSize'].describe()
# Out:
# count    84.000000
# mean      2.805952
# std       0.994727
# min       1.300000
# 25%       2.175000
# 50%       2.500000
# 75%       3.400000
# max       5.700000
# Name: EngineSize, dtype: float64

# %% [markdown]
# # Bivariate Analysis

# %%
# Continuous Vs Continuous
# Scatter plot

# %%
plt.figure(figsize=(3,4))
plt.scatter(df['Price'],df['EngineSize'])
plt.xlabel("Price")
plt.ylabel("EngineSize")
# Out:
# Text(0, 0.5, 'EngineSize')

# %%
plt.figure(figsize=(3,4))
plt.scatter(df['Price'],df['MPG.city'])
plt.xlabel("Price")
plt.ylabel("EngineSize")
# Out:
# Text(0, 0.5, 'EngineSize')

# %% [markdown]
# There is positive correlation between EngineSize and Price

# %%
df['Price'].corr(df['EngineSize'])
# Out:
# np.float64(0.5974253916659132)

# %%
#l1=['EngineSize','Weight','Horsepower']
df[['EngineSize','Weight','Horsepower','MPG.city','RPM','MPG.highway']].corrwith(df['Price'])
#df['Price'].corr(df[l1])
# Out:
# EngineSize     0.597425
# Weight         0.647179
# Horsepower     0.788218
# MPG.city      -0.594562
# RPM           -0.004955
# MPG.highway   -0.560680
# dtype: float64

# %% [markdown]
# Categorical vs Categorical

# %%
# CrossTab
# type and AirBag
pd.crosstab(df['Type'],df['AirBags'])
# Out:
# AirBags  Driver & Passenger  Driver only
# Type
# Compact                   2           14
# Large                     3            8
# Midsize                   6           16
# Small                     0           21
# Sporty                    3           11
# Van                       0            9

# %% [markdown]
# Small and Van type of vehicles has Driver only Air Bags

# %%
pd.crosstab(df['Type'],df['Origin'])
# Out:
# Origin   USA  non-USA
# Type
# Compact    7        9
# Large     11        0
# Midsize   10       12
# Small      7       14
# Sporty     8        6
# Van        5        4

# %%
# heatmap
plt.figure(figsize=(3,4))
tcb=pd.crosstab(df['Type'],df['Origin'])
sns.heatmap(tcb,annot=True)
# Out:
# <Axes: xlabel='Origin', ylabel='Type'>

# %% [markdown]
# Categorical versus Continuous

# %%
# Price Vs AirBags
# BoxPlot
plt.figure(figsize=(3,3))
sns.boxplot(x='AirBags',y='Price',data=df)
# Out:
# <Axes: xlabel='AirBags', ylabel='Price'>

# %%
df['Type'].value_counts()
# Out:
# Type
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.boxplot(x='Price',y='Origin',data=df)
# Out:
# <Axes: xlabel='Price', ylabel='Origin'>

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
sns.pairplot(df,x_vars=['EngineSize','Horsepower','Weight','MPG.city'],y_vars='Price')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Export the dataframe to a csv file
df.isnull().sum()
# Out:
# id                    0
# Manufacturer          0
# Model                 0
# Type                  0
# Min.Price             0
# Price                 0
# Max.Price             0
# MPG.city              0
# MPG.highway           0
# AirBags               0
# DriveTrain            0
# Cylinders             0
# EngineSize            0
# Horsepower            0
# RPM                   0
# Rev.per.mile          0
# Man.trans.avail       0
# Fuel.tank.capacity    0
# Passengers            0
# Length                0
# Wheelbase             0
# Width                 0
# Turn.circle           0
# Rear.seat.room        0
# Luggage.room          0
# Weight                0
# Origin                0
# Make                  0
# dtype: int64

# %% [markdown]
# # Exporting DataFrame to Csv file

# %%
df.to_csv(r'C:\Users\dabha\OneDrive\Documents\CoachX\Evening_Python\Clean_Car_Data1.csv')

# %%
Compact_Cars=df[df['Type']=='Compact']

# %%
Compact_Cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 2 to 91
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  16 non-null     int64
#  1   Manufacturer        16 non-null     object
#  2   Model               16 non-null     object
#  3   Type                16 non-null     object
#  4   Min.Price           16 non-null     float64
#  5   Price               16 non-null     float64
#  6   Max.Price           16 non-null     float64
#  7   MPG.city            16 non-null     int64
#  8   MPG.highway         16 non-null     int64
#  9   AirBags             16 non-null     object
#  10  DriveTrain          16 non-null     object
#  11  Cylinders           16 non-null     object
#  12  EngineSize          16 non-null     float64
#  13  Horsepower          16 non-null     int64
#  14  RPM                 16 non-null     int64
#  15  Rev.per.mile        16 non-null     int64
# ...
